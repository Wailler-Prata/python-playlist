# %% [markdown]
# # Exercicio 16

# %%
from google.colab import files
src = list (files.upload ().values ())[0]
open ("corona_virus.csv", "wb").write (src)
# Out:
#      <input type="file" id="files-a5348891-f2ca-4768-8e2a-609561a291a5" name="files[]" multiple disabled />
#      <output id="result-a5348891-f2ca-4768-8e2a-609561a291a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving corona_virus.csv to corona_virus.csv
# 96261

# %%
import pandas as pd
dataset = pd.read_csv ("corona_virus.csv", sep = ",")

# %% [markdown]
#  * 1. Quantas colunas o "data set" possui?
#  * 2. Quais são os nomes e tipos das colunas do "data set"?
#  * 3. Quantas entradas, linhas, o "data set" possui?
#  * 4. Qual o espaço de memória ocupado pelo "data set"?

# %%
dataset = pd.read_csv("corona_virus.csv", sep =",")
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2727 entries, 0 to 2726
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2727 non-null   object
#  1   region  2727 non-null   object
#  2   state   2727 non-null   object
#  3   cases   2727 non-null   int64
#  4   deaths  2727 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 106.6+ KB

# %% [markdown]
# * 5. Quais são as 10 primeiras linhas do "data set"?

# %%
dataset = pd.read_csv ("corona_virus.csv", sep = ",")
dataset.head (10)
# Out:
#          date        region               state  cases  deaths
# 0  2020-01-30  Centro-Oeste    Distrito Federal      0       0
# 1  2020-01-30  Centro-Oeste               Goiás      0       0
# 2  2020-01-30  Centro-Oeste         Mato Grosso      0       0
# 3  2020-01-30  Centro-Oeste  Mato Grosso do Sul      0       0
# 4  2020-01-30      Nordeste             Alagoas      0       0
# 5  2020-01-30      Nordeste               Bahia      0       0
# 6  2020-01-30      Nordeste               Ceará      0       0
# 7  2020-01-30      Nordeste            Maranhão      0       0
# 8  2020-01-30      Nordeste             Paraíba      0       0
# 9  2020-01-30      Nordeste          Pernambuco      0       0

# %% [markdown]
# * 6. Quantas entradas do "data set" reportam mais de 1.000 casos confirmados da COVID-19?

# %%
dataset = pd.read_csv ("corona_virus.csv", sep = ",")
dataset.loc[dataset["cases"] > 1000]
# Out:
#             date   region              state  cases  deaths
# 1535  2020-03-26  Sudeste          São Paulo   1052      58
# 1562  2020-03-27  Sudeste          São Paulo   1223      68
# 1589  2020-03-28  Sudeste          São Paulo   1406      84
# 1616  2020-03-29  Sudeste          São Paulo   1451      98
# 1643  2020-03-30  Sudeste          São Paulo   1517     113
# ...          ...      ...                ...    ...     ...
# 2722  2020-05-09  Sudeste     Rio de Janeiro  16929    1653
# 2723  2020-05-09  Sudeste          São Paulo  44411    3608
# 2724  2020-05-09      Sul             Paraná   1785     107
# 2725  2020-05-09      Sul  Rio Grande do Sul   2493      95
# 2726  2020-05-09      Sul     Santa Catarina   3372      64
#
# [410 rows x 5 columns]

# %% [markdown]
#  * 7. Quantas entradas do "data set" reportam mais de 2.000 mortes por COVID-19?

# %%
dataset = pd.read_csv ("corona_virus.csv", sep = ",")
dataset.loc[dataset["deaths"] > 2000]
# Out:
#             date   region      state  cases  deaths
# 2426  2020-04-28  Sudeste  São Paulo  24041    2049
# 2453  2020-04-29  Sudeste  São Paulo  26158    2247
# 2480  2020-04-30  Sudeste  São Paulo  28698    2375
# 2507  2020-05-01  Sudeste  São Paulo  30374    2511
# 2534  2020-05-02  Sudeste  São Paulo  31174    2586
# 2561  2020-05-03  Sudeste  São Paulo  31772    2627
# 2588  2020-05-04  Sudeste  São Paulo  32187    2654
# 2615  2020-05-05  Sudeste  São Paulo  34053    2851
# 2642  2020-05-06  Sudeste  São Paulo  37853    3045
# 2669  2020-05-07  Sudeste  São Paulo  39928    3206
# 2696  2020-05-08  Sudeste  São Paulo  41830    3416
# 2723  2020-05-09  Sudeste  São Paulo  44411    3608

# %% [markdown]
# * 8. Quais são as regiões reportadas no "data set"? Apresentar cada região de forma única

# %%
dataset = pd.read_csv ("corona_virus.csv", sep = ",")
dataset.region.unique ()
# Out:
# array(['Centro-Oeste', 'Nordeste', 'Norte', 'Sudeste', 'Sul'],
#       dtype=object)

# %% [markdown]
# * 9. Quais são os estados reportados no "data set"? Apresentar cada estado de forma única.

# %%
dataset = pd.read_csv ("corona_virus.csv", sep = ",")
dataset.state.unique ()
# Out:
# array(['Distrito Federal', 'Goiás', 'Mato Grosso', 'Mato Grosso do Sul',
#        'Alagoas', 'Bahia', 'Ceará', 'Maranhão', 'Paraíba', 'Pernambuco',
#        'Piauí', 'Rio Grande do Norte', 'Sergipe', 'Acre', 'Amapá',
#        'Amazonas', 'Pará', 'Rondônia', 'Roraima', 'Tocantins',
#        'Espírito Santo', 'Minas Gerais', 'Rio de Janeiro', 'São Paulo',
#        'Paraná', 'Rio Grande do Sul', 'Santa Catarina'], dtype=object)

# %% [markdown]
# * 10. Quais são os registros em que o estado é Minas Gerais? Quantos são esses registros?

# %%
dataset = pd.read_csv ("corona_virus.csv", sep = ",")
dataset.loc[dataset["state"] == "Minas Gerais"].count()
# Out:
#             date   region         state  cases  deaths
# 21    2020-01-30  Sudeste  Minas Gerais      0       0
# 48    2020-01-31  Sudeste  Minas Gerais      0       0
# 75    2020-02-01  Sudeste  Minas Gerais      0       0
# 102   2020-02-02  Sudeste  Minas Gerais      0       0
# 129   2020-02-03  Sudeste  Minas Gerais      0       0
# ...          ...      ...           ...    ...     ...
# 2613  2020-05-05  Sudeste  Minas Gerais   2452      94
# 2640  2020-05-06  Sudeste  Minas Gerais   2605      97
# 2667  2020-05-07  Sudeste  Minas Gerais   2770     106
# 2694  2020-05-08  Sudeste  Minas Gerais   2943     111
# 2721  2020-05-09  Sudeste  Minas Gerais   3123     118
#
# [101 rows x 5 columns]

# %% [markdown]
# * 11. Quantos são os registros em que a região é Norte?

# %%
dataset = pd.read_csv ("corona_virus.csv", sep = ",")
dataset.loc[dataset["region"] == "Norte"].count()
# Out:
# date      707
# region    707
# state     707
# cases     707
# deaths    707
# dtype: int64

# %% [markdown]
#  * 12. Qual é o número médio de casos de infecção por COVID-19 reportados no "data set"?

# %%
dataset.cases.mean ()
# Out:
# 787.6707004033736

# %% [markdown]
# * 13. Qual é o número médio de mortes por COVID-19 reportados no "data set"?

# %%
dataset.deaths.mean ()
# Out:
# 51.52585258525853

# %% [markdown]
#  * 14. Qual é o número máximo de casos de infecção por COVID-19 reportados no "data set"?

# %%
dataset.cases.max ()
# Out:
# 44411

# %% [markdown]
# * 15. Qual é o número máximo de mortes por COVID-19 reportados no "data set"?

# %%
dataset.deaths.max ()
# Out:
# 3608

# %% [markdown]
#  * 16. A partir de qual quartil (Q1 = 25%, Q2 = 50% e Q3 = 75%) o número de casos de infecção
# por COVID-19 é maior que zero?

# %%
dataset = pd.read_csv ("corona_virus.csv", sep = ",")
dataset.cases.describe ()
# Out:
# count     2727.000000
# mean       787.670700
# std       2945.525757
# min          0.000000
# 25%          0.000000
# 50%          7.000000
# 75%        350.000000
# max      44411.000000
# Name: cases, dtype: float64

# %% [markdown]
# * 17. A partir de qual quartil (Q1 = 25%, Q2 = 50% e Q3 = 75%) o número de mortes por COVID19 é maior que zero?

# %%
dataset = pd.read_csv ("corona_virus.csv", sep = ",")
dataset.deaths.describe ()
# Out:
# count    2727.000000
# mean       51.525853
# std       237.048787
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        11.000000
# max      3608.000000
# Name: deaths, dtype: float64
