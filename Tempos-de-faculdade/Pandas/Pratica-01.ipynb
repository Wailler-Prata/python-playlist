# %% [markdown]
# # Carregando arquivos para manipulação

# %%
from google.colab import files
src = list (files.upload ().values ())[0]
open ("kc_house_data.csv", "wb").write (src)
# Out:
#      <input type="file" id="files-0ef7462b-738d-4140-a89a-8f46f7c3edba" name="files[]" multiple disabled />
#      <output id="result-0ef7462b-738d-4140-a89a-8f46f7c3edba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kc_house_data.csv to kc_house_data.csv
# 2381977

# %%
import pandas as pd
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")

# %% [markdown]
#  * "DataFrame" é um tipo da biblioteca Pandas para armazenamento de dados. Ele permite a
# manipulação de dados na memória principal

# %%
import pandas as pd
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
type (dataset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# * O método "info ()" de um "DataFrame" permite que vejamos informação sobre o "data set".
# O exemplo apresenta, por exemplo, o total de
# colunas do "data set", o tipo de cada coluna e o espaço de memória usado para armazenar o
# "data set".

# %%
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(6), int64(14), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# * Podemos estabelecer relações entre comandos SQL e métodos da biblioteca Pandas. Por
# exemplo:

# %%
from google.colab import files
src = list (files.upload ().values ())[0]
open ("tabelaSQLPandas.png", "wb").write (src)
# Out:
#      <input type="file" id="files-b19fcfe9-521d-49a6-a535-21edd89c07f5" name="files[]" multiple disabled />
#      <output id="result-b19fcfe9-521d-49a6-a535-21edd89c07f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tabelaSQLPandas.png to tabelaSQLPandas.png
# 80479

# %%
from IPython.display import Image
Image ("tabelaSQLPandas.png")

# %% [markdown]
# * Podemos visualizar os registros do "DataFrame" apenas informando o nome da varíavel que
# o referencia, no caso "dataset".

# %%
print (dataset)
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %% [markdown]
# * Também podemos visualizar os registros através da função "print ()".

# %%
print (dataset)
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %% [markdown]
# * O método "head ()" de um "DataFrame" permite que vejamos alguns de seus registros
# iniciais, em geral, as 5 primeiros registros.

# %%
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.head ()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# * O método "head ()" permite que especifiquemos como argumento o número de registros a
# serem apresentados

# %%
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.head (7)
# Out:
#            id             date      price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000   221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000   538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000   180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000   604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000   510000.0  ... -122.045           1800        7503
# 5  7237550310  20140512T000000  1225000.0  ... -122.005           4760      101930
# 6  1321400060  20140627T000000   257500.0  ... -122.327           2238        6819
#
# [7 rows x 21 columns]

# %% [markdown]
# * Podemos filtrar registros usando o atributo "loc[]". O atributo "loc[]" recebe uma expressão
# para realizar a filtragem.

# %%
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.loc[dataset["bedrooms"] > 7]
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 1660   9126101740  20141204T000000  ...           1800        2580
# 4035    685000115  20141007T000000  ...           2050        9100
# 4067   7226500100  20150219T000000  ...           1480        4942
# 4096   1997200215  20140507T000000  ...           1460        6291
# 4235   2902200015  20150106T000000  ...           1960        2450
# 6079   9822700190  20140808T000000  ...           2510        5000
# 6174   1873400020  20140703T000000  ...           1760        7624
# 8546    424049043  20140811T000000  ...           1448        3866
# 8757   1773100755  20140821T000000  ...           1420        4960
# 9077   6746700615  20150318T000000  ...           1610        3000
# 9452   2769600590  20141016T000000  ...           1560        3737
# 10958  1652500060  20140711T000000  ...           3670       20500
# 12885  8813400155  20141219T000000  ...           2170        3750
# 13314   627300145  20140814T000000  ...           2730       10400
# 15070  7418000130  20141211T000000  ...           1780       10457
# 15161  5566100170  20141029T000000  ...           2040       11914
# 15670  8141200080  20140814T000000  ...           1540        4800
# 15870  2402100895  20140625T000000  ...           1330        4700
# 16844  8823900290  20150317T000000  ...           2710        4320
# 17235  1338600225  20140528T000000  ...           4440        8640
# 18443  8823901445  20150313T000000  ...           2460        4400
# 18477  1346300150  20141020T000000  ...           4210        8325
# 19254  8812401450  20141229T000000  ...           1810        3745
# 19302  3756900027  20141125T000000  ...           1380        8172
#
# [24 rows x 21 columns]

# %% [markdown]
# * O método "unique ()" permite retornar registros únicos do "DataFrame".

# %%
#Identificadores sem repetições:
import pandas as pd
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.id.unique ()
# Out:
# array([7129300520, 6414100192, 5631500400, ..., 1523300141,  291310100,
#        1523300157])

# %% [markdown]
# * OU

# %%
#Quartos sem repetições:
import pandas as pd
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.bedrooms.unique ()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33])

# %% [markdown]
#  * O método "count ()" permite que calculemos o número total de registros (número de linhas)
# do "DataFrame" considerando cada coluna ou uma coluna específica.

# %%
#Número total de registros do DataFrame considerando cada coluna:
import pandas as pd
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.count ()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21611
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %% [markdown]
#  * OU

# %%
#Número total de registros do DataFrame considerando a coluna bedrooms:
import pandas as pd
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.bedrooms.count ()
# Out:
# 21613

# %% [markdown]
#  * O método "mean ()" permite que calculemos a média aritmética dos valores de cada coluna
# do "DataFrame" ou de uma coluna específica.

# %%
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.mean ()
# Out:
# id               4.580302e+09
# price            5.400881e+05
# bedrooms         3.370842e+00
# bathrooms        2.114757e+00
# sqft_living      2.079900e+03
# sqft_lot         1.510697e+04
# floors           1.494309e+00
# waterfront       7.541757e-03
# view             2.343034e-01
# condition        3.409430e+00
# grade            7.656873e+00
# sqft_above       1.788396e+03
# sqft_basement    2.915090e+02
# yr_built         1.971005e+03
# yr_renovated     8.440226e+01
# zipcode          9.807794e+04
# lat              4.756005e+01
# long            -1.222139e+02
# sqft_living15    1.986552e+03
# sqft_lot15       1.276846e+04
# dtype: float64

# %% [markdown]
#  * OU

# %%
#Média aritmética do número de quartos:

dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.bedrooms.mean ()
# Out:
# 3.37084162309721

# %% [markdown]
#  * O atributo "columns" armazena o nome das colunas do "DataFrame".

# %%
#Nome das colunas:
import pandas as pd
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
#  * O método "describe ()" retorna informação estatística sobre o "DataFrame" considerando
# cada coluna separadamente, como número de registros, média aritmética, desvio padrão,
# valor mínimo, quartis e valor máximo. O método considera apenas as colunas com valores
# núméricos. Colunas com valores não numéricos são descartadas da análise estatística.

# %%
#Informação estatística sobre o DataFrame:
import pandas as pd
dataset = pd.read_csv ("kc_house_data.csv", sep = ",")
dataset.describe ()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  2.161300e+04  ...   21613.000000   21613.000000
# mean   4.580302e+09  5.400881e+05  ...    1986.552492   12768.455652
# std    2.876566e+09  3.671272e+05  ...     685.391304   27304.179631
# min    1.000102e+06  7.500000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.219500e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]
