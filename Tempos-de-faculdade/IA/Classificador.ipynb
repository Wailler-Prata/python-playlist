# %% [markdown]
# # Importando bibliotecas e carregando o Conjunto de Dados

# %%
# Bibliotecaas
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Conjunto de dados
data = load_breast_cancer()

# %%
data['data']
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %% [markdown]
# # Organizando os dados

# %%
# Organizar nossos dados
label_names = data['target_names']
rotulos = data['target']
feature_names = data['feature_names']
caracteristicas = data['data']

# Olhando para os nossos dados
print(label_names)
print('Class label = ', labels[1])
print(feature_names)
print(features[1])
# Out:
# ['malignant' 'benign']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0d9e6cb8684b> in <module>()
#       7 # Olhando para os nossos dados
#       8 print(label_names)
# ----> 9 print('Class label = ', labels[1])
#      10 print(feature_names)
#      11 print(features[1])
#
# NameError: name 'labels' is not defined

# %% [markdown]
# # Divisão dos dados em treinamento e teste

# %%
X_treino, X_teste, Y_rotulos_treino, Y_rotulos_teste = train_test_split(caracteristicas,
                                                          rotulos,
                                                          test_size=0.30,
                                                          random_state=42)

# %% [markdown]
# #Constroi o objeto do Classificador

# %%
# Inicializar nosso classificador
classificador = GaussianNB()

# %% [markdown]
# #Treina o classificador

# %%
# Treinar nosso classificador
modelo = classificador.fit(X_treino, Y_rotulos_treino)

# %% [markdown]
# #Aplica as previsões no conjunto de treino

# %%
# Fazer previsões
previsoes = classificador.predict(teste)
print(previsoes)

# %% [markdown]
# #Avalia o desempenho do classificador

# %%
# Avaliar a precisão
print(accuracy_score(rotulos_teste, previsoes))
