# %% [markdown]
# # while

# %%
i = 0
while i < 5:
 print (i)
 i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # break

# %%
i = 0
while i < 5:
 if i == 3:
   break
 print (i)
 i += 1
# Out:
# 0
# 1
# 2

# %% [markdown]
# # continue

# %%
i = 0
while i < 5:
 print (i)
 i += 1
else:
 print ("Fim da estrutura de repetição. \n\tValor final da variável i:", i)
# Out:
# 0
# 1
# 2
# 3
# 4
# Fim da estrutura de repetição.
# 	Valor final da variável i: 5
