# %% [markdown]
# # Exemplo

# %% [markdown]
# # elif
# num1, num2 = int (input ("Informe o primeiro número: ")), int (input ("
# Informe o segundo número: "))
# if num1 < num2:
#  print("O primeiro número informado é menor que o segundo.")
# elif num1 == num2:
#  print("Os dois números informados são iguais.")

# %% [markdown]
# # Comparações Abreviadas
# num1, num2 = int (input ("Informe o primeiro número: ")), int (input ("
# Informe o segundo número: "))
# if num1 > num2: print ("O primeiro número informado é maior que o segun
# do.")

# %% [markdown]
# num1, num2 = int (input ("Informe o primeiro número: ")), int (input ("
# Informe o segundo número: "))
# if num1 > num2: print ("O primeiro número informado é maior que o segun
# do.")

# %% [markdown]
# num1, num2 = int (input ("Informe o primeiro número: ")), int (input ("
# Informe o segundo número: "))
# print ("Maior:", num1) if num1 > num2 else print ("Maior:", num2)

# %% [markdown]
# num1, num2 = int (input ("Informe o primeiro número: ")), int (input ("
# Informe o segundo número: "))
# print ("Maior:", num1) if num1 > num2 else print
# ("Os números são iguais.") if num1 == num2 else print ("Maior:", num2)

# %% [markdown]
# # Negação (not)

# %% [markdown]
# num1, num2 = int (input ("Informe o primeiro número: ")), int (input ("
# Informe o segundo número: "))
# if not num1 >= num2:
#  print ("Maior:", num2)
# else:
#  if not num1 == num2:
#  print ("Maior:", num1)
#  else:
#  print ("Os números são iguais.")

# %% [markdown]
# # Disjunção (or)

# %% [markdown]
# num1, num2, num3 = int (input ("Informe o primeiro número: ")), int (in
# put ("Informe o segundo número: ")), int (input ("Informe o terceiro nú
# mero: "))
# if num1 > num2 or num1 > num3:
#  print ("O primeiro número é, pelo menos, maior que um dos outros dois
# números informados.")

# %% [markdown]
# # Conjunção (and)

# %% [markdown]
# num1, num2, num3 = int (input ("Informe o primeiro número: ")), int (in
# put ("Informe o segundo número: ")), int (input ("Informe o terceiro nú
# mero: "))
# if num1 > num2 and num1 > num3:
#  print ("Maior:", num1)

# %% [markdown]
# # if aninhado

# %% [markdown]
# nota1, nota2, nota3 = int (input ("Nota 01: ")), int (input ("Nota 02:
# ")), int (input ("Nota 03: "))
# total = nota1 + nota2 + nota3
# print ("Nota total:", total)
# if total >= 60:
#  if total >= 80: print ("Aluno aprovado com louvor.")
#  else: print ("Aluno aprovado.")
#  else:
#  if total >= 40: print ("Aluno em recuperação.")
#  else: print ("Aluno reprovado.")
