# %% [markdown]
# # Exercício

# %% [markdown]
#  * 1. Execute o trecho de código abaixo. Em seguida, escreva sobre a saída retornada como
# resposta.

# %%
lista = [1, 67.2, True, "Ana Conda"]
print ("Lista:", lista)
lista.remove (True)
lista.remove (True)
print ("Nova lista:", lista)
# Out:
# Lista: [1, 67.2, True, 'Ana Conda']
# Nova lista: [67.2, 'Ana Conda']

# %% [markdown]
# * RE: O remove entende que o primeiro parametro que possui valor = 1  é do tipo boleano, isso é decorrente dos binários onde o 1 quer dizer True/Positivo e o segundo quer dizer False/ Negativo

# %% [markdown]
# 2. Escreva um algoritmo que leia números informados pelo usuário a partir do teclado. Os
# números devem ser inseridos em uma lista chamada lista_original. O usuário deve
# informar quantos números ele desejar. Após ler todos os números informados pelo
# usuário, o algoritmo deve copiar os valores ímpares da lista_original para uma lista
# chamada lista_impares e também copiar os valores pares da lista_original para uma lista
# chamada lista_pares. Todas as listas devem ser apresentadas na tela.

# %%
numero1 = int(input("Informe o primeiro numero: "))
numero2 = int(input("Informe o primeiro numero: "))
numero3 = int(input("Informe o primeiro numero: "))
numero4 = int(input("Informe o primeiro numero: "))

lista = [numero1, numero2, numero3, numero4]
par = []
impar = []

for x in lista:
  if x % 2 == 0:
    par.append(x)
  else:
    impar.append(x)
print(par)
print(impar)
# Out:
# Informe o primeiro numero: 1
# Informe o primeiro numero: 2
# Informe o primeiro numero: 3
# Informe o primeiro numero: 4
# [2, 4]
# [1, 3]

# %% [markdown]
# * 3. Escreva um algoritmo que leia duas listas de valores informados pelo usuário a partir do
# teclado. O algoritmo deve gerar uma nova lista que seja a união das duas listas
# informadas pelo usuário. Assim, a nova lista deve conter todos os valores presentes nas duas listas lidas a partir do teclado. A nova lista não deve conter valores repetidos. Todas
# as listas devem ser apresentadas na tela.

# %%
lista1 = []
for x in range(2):
  numero1 = int(input("Informe o primeiro numero da l1: "))
  lista1.append(numero1)

lista2 = []
for x in range(1):
  numero2 = int(input("Informe o primeiro numero da l2: "))
  lista2.append(numero2)

print("Primeira Lista: ", lista1)
print("Segunda Lista: ", lista2)

novaLista = []

for x in lista1:
  novaLista.append(x)

for x in lista2:
  novaLista.append(x)
loope = 0
count = 0

for x in novaLista:

  for y in novaLista:

    if x == y and count < 2:
      count = count + 1

    elif x == y and count >= 2:
      novaLista.remove(y)

print("Nova lista: ", novaLista)
# Out:
# Informe o primeiro numero da l1: 3
# Informe o primeiro numero da l1: 3
# Informe o primeiro numero da l2: 1
# Primeira Lista:  [3, 3]
# Segunda Lista:  [1]
# Nova lista:  [3, 1]

# %% [markdown]
# * 4. Escreva um algoritmo que leia duas listas de valores informados pelo usuário a partir do
# teclado. O algoritmo deve gerar uma nova lista que seja a interseção das duas listas
# informadas pelo usuário. Assim, a nova lista deve conter apenas os valores comuns às
# duas listas lidas a partir do teclado. A nova lista não deve conter valores repetidos. Todas
# as listas devem ser apresentadas na tela.

# %%
lista1 = []
for x in range(2):
  numero1 = int(input("Informe o primeiro numero da l1: "))
  lista1.append(numero1)

lista2 = []
for x in range(1):
  numero2 = int(input("Informe o primeiro numero da l2: "))
  lista2.append(numero2)

print("Primeira Lista: ", lista1)
print("Segunda Lista: ", lista2)

novaLista = []

for x in lista1:
  novaLista.append(x)

for x in lista2:
  novaLista.append(x)
loope = 0
count = 0

for x in novaLista:

  for y in novaLista:

    if x == y and count >= 2:
      count = count + 1

    elif x == y and count < 2:
      novaLista.remove(y)

print("Nova lista: ", novaLista)
# Out:
# Informe o primeiro numero da l1: 1
# Informe o primeiro numero da l1: 2
# Informe o primeiro numero da l2: 2
# Primeira Lista:  [1, 2]
# Segunda Lista:  [2]
# Nova lista:  [2]

# %% [markdown]
# * 5. Escreva um algoritmo que leia números informados pelo usuário a partir do teclado. Os
# números devem ser inseridos em uma lista. O usuário deve informar quantos números
# ele desejar. Após ler todos os números informados pelo usuário, o algoritmo deve
# apresentar na tela:
# a. A média aritmética dos números informados.
# b. O desvio padrão em relação à média aritmética dos números informados

# %%
lista = []
qnt = int(input("informe a quantidade de numeros que serão informados"))
for x in range(qnt):
    numero = float(input("Infome o numero"))
    lista.append(numero)
print(lista)

soma = 0
for x in lista:
  soma = soma + x
aritimetica = soma / qnt
print("A média aritimética é: %f" %aritimetica)

# Calculando o desvio Padrão
import math
somadp = 0
for y in lista:
  somadp = somadp + math.pow(y - aritimetica,2)
desvio = math.sqrt(somadp/ 3)
print("O desvio padrão e´: %f" %desvio)
# Out:
# informe a quantidade de numeros que serão informados3
# Infome o numero1.55
# Infome o numero1.70
# Infome o numero1.80
# [1.55, 1.7, 1.8]
# A média aritimética é: 1.683333
# 0.10274023338281627

# %% [markdown]
# * 6. Faça uma pesquisa sobre os métodos de lista em Python apresentados abaixo. Em
# seguida, apresente exemplos que demonstrem a utilização de cada um desses métodos.
# Apresente as explicações de cada um deles no seu notebook na forma de comentários
# Markdown juntamente com os exemplos.
# a. count ()
# b. index ()
# c. reverse ()
# d. sort ()

# %%
# count() Retorna o número de vezes que o valor 9 aparece na lista:
points = [1, 4, 2, 9, 7, 8, 9, 3, 1]
x = points.count(9)
print(x)

# index() Qual é a posição do valor "cherry":
fruits = ['apple', 'banana', 'cherry']
y = fruits.index("cherry")
print(y)

# reverse () é um método embutido na linguagem de programação Python que inverte os objetos da lista no local.
fruits = ['apple', 'banana', 'cherry']
print(fruits)

# sort() Classifique a lista em ordem alfabética ou crescente:
cars = ['Ford', 'BMW', 'Volvo']
cars.sort()
print(cars)
# Out:
# 2
# 2
# ['apple', 'banana', 'cherry']
# ['BMW', 'Ford', 'Volvo']

# %% [markdown]
#  * 7. . Faça uma pesquisa sobre as funções Python apresentados abaixo. Em seguida, apresente
# exemplos que demonstrem a utilização de cada uma delas. Apresente as explicações de
# cada uma delas no seu notebook na forma de texto Markdown juntamente com os
# exemplos.
# a. min ()
# b. max ()

# %%
# min() Retorne o número mais baixo:
x = min(5, 10)
print(x)

# max() Retorne o número mais alto:
x = max(5, 10)
print(x)
# Out:
# 5
# 10
