# %% [markdown]
# # Exercício

# %% [markdown]
# * 1. Escreva um algoritmo que solicite como entrada um limite inferior natural e um limite
# superior também natural. O algoritmo deve apresentar na tela todos os números pares
# entre o limite inferior e superior. Os limites inferior e superior devem ser apresentados
# se também forem números pares.

# %%
numero1 = int(input("Informe o primeiro numero inferior natural: "))
numero2 = int(input("Informe o segundo numero superior natural: "))

while numero1 <= numero2:
  print(numero1)
  numero1 = numero1 + 1
# Out:
# Informe o primeiro numero inferior natural: 2
# Informe o segundo numero superior natural: 5
# 2
# 3
# 4
# 5

# %% [markdown]
# * 2. O fatorial de um número n é representado por n! e é calculado como apresentado abaixo:
#  n! = n x (n – 1) x (n – 2) x ... x 2 x 1, para n > 0 e 0! = 1.
#
# Exemplos:
#
#  5! = 5 x 4 x 3 x 2 x 1 = 120
#  4! = 4 x 3 x 2 x 1 = 24
#  3! = 3 x 2 x 1 = 6
#  2! = 2 x 1 = 2
#  1! = 1
#  0! = 1 (OBS: o fatorial de 0 é sempre 1).
# Escreva um algoritmo que leia um número natural informado pelo usuário a partir do
# teclado e que apresente como saída o fatorial desse número. Se o usuário inserir um
# número negativo, o algoritmo deve informar que o número é inválido.

# %%
numero = int(input("Informe um numero: "))

resultado = 1
count = 1
while count <= numero:
  resultado = resultado * count
  count = count + 1
print("O fatorial do numero %d é igual a: %d" %(numero,resultado))
# Out:
# Informe um numero5
# O fatorial do numero 5 é igual a: 120
