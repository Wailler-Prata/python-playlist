# %% [markdown]
# #Prática - 03

# %% [markdown]
# * 1. Escreva um algoritmo em linguagem de programação Python que lê as coordenadas de
# dois pontos no plano cartesiano e imprima a distância entre estes dois pontos.
# OBS.: fórmula da distância entre dois pontos A (x1, y1) e B (x2, y2):

# %%
import math
pontox1 = int(input("Informe a abscissa do primeiro ponto (x1)"))
pontoy1 = int(input("Informe a abscissa do primeiro ponto (y1)"))
pontox2 = int(input("Informe a abscissa do primeiro ponto (x2)"))
pontoy2 = int(input("Informe a abscissa do primeiro ponto (y2)"))

distancia = math.sqrt(math.pow((pontox2 - pontox1),2) + math.pow((pontoy2 - pontoy1),2))

print("A distância entre os dois pontos é: %f" %distancia)
# Out:
# Informe a abscissa do primeiro ponto (x1)2
# Informe a abscissa do primeiro ponto (y1)2
# Informe a abscissa do primeiro ponto (x2)4
# Informe a abscissa do primeiro ponto (y2)4
# A distância entre os dois pontos é: 2.828427

# %% [markdown]
# * Escreva um algoritmo em linguagem de programação Python que recebe 3 valores reais
# informados pelo usuário. O algoritmo deve indicar o maior deles, o menor deles e a média
# aritmética desses números.

# %%
numero1 = int(input("Informe o primeiro numero: "))
numero2 = int(input("Informe o segundo numero: "))
numero3 = int(input("Informe o terceiro numero: "))



# Calcula o maior numero
if numero1 > numero2 and numero1 > numero3:
  print("O maior numero é: %d" %numero1)

elif numero2 > numero1 and numero2 > numero3:
  print("O maior numero é: %d" %numero2)

elif numero3 > numero1 and numero3 > numero2:
  print("O maior numero é: %d" %numero3)



# Calcula o menor numero
if numero1 < numero2 and numero1 < numero3:
  print("O menor numero é: %d" %numero1)

elif numero2 < numero1 and numero2 < numero3:
  print("O menor numero é: %d" %numero2)

elif numero3 < numero1 and numero3 < numero2:
  print("O menor numero é: %d" %numero3)

media = (numero1 + numero1 + numero1) /3

print("A média é: %f" %media)
# Out:
# Informe o primeiro numero5
# Informe o segundo numero4
# Informe o terceiro numero3
# 5
# 3
# A média é: 5.000000

# %% [markdown]
# * 3. Escreva um algoritmo em linguagem de Programação Python que resolva uma equação
# de segundo grau, realizando a verificação de consistência dos valores dos coeficientes
# ("a", "b" e "c") e do discriminante (delta).
# a. Se os coeficientes "a" e "b" forem iguais a zero e o coeficiente "c" for diferente de
# ze

# %% [markdown]
# * a. Se os coeficientes "a" e "b" forem iguais a zero e o coeficiente "c" for diferente de
# zero, apresentar a mensagem "Coeficientes informados incorretamente."

# %% [markdown]
# * b. Caso o coeficiente "a" seja igual a zero e o coeficiente "b" for diferente de zero,
# deverá ser impressa a mensagem: "Essa é uma equação de primeiro grau" e
# deverá ser informado o valor da raiz real da equação.

# %% [markdown]
# * c. Caso o discriminante seja negativo, deverá ser impressa a mensagem: "Esta
# equação não possui raízes reais"

# %% [markdown]
# * d. Caso o discriminante seja zero, apresentar a mensagem "Esta equação possui
# duas raízes reais iguais. " e informar o valor das raízes da equação.

# %% [markdown]
# * e. Caso o discriminante seja maior que zero, apresentar a mensagem "Esta equação
# possui duas raízes reais diferentes. " e informar o valor das raízes da equação.
# Equação do segundo grau: ax2 + bx + c = 0
# Discriminante:  = b2 – 4ac

# %%
import math
a = int(input("Informe o valor de A: "))
b = int(input("Informe o valor de B: "))
c = int(input("Informe o valor de C: "))

delta =  math.pow(b,2) - 4 * a * c

if a == 0 and b == 0 and c != 0:
  print("Coeficientes informados incorretamente")
elif a == 0 and b != 0:
  print("Essa é uma equação de primeiro grau")
  raiz = c/b
  print("O valor da raiz é %f" %raiz )

if delta < 0:
  print("Esta equação não possui raízes reais")
elif delta == 0:
  print("Esta equação possui duas raízes reais iguais, o valor das raizes é: %f" %delta)
elif delta > 0:
  x1 = (-b) + math.sqrt(delta) / 2 * a
  x2 = (-b) + math.sqrt(delta) / 2 * a
  print("A primeira raiz x' é: %f" %x1)
  print("A segunda raiz x'' é: %f" %x2)
# Out:
# Informe o valor de A: 3
# Informe o valor de B: 6
# Informe o valor de C: 2
# A primeira raiz x' é: -0.803848
# A segunda raiz x'' é: -0.803848
